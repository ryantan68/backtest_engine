# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
import copy
import matplotlib.pyplot as plt
from single_asset_strategies import *
from strategy_builder import *

# %%
df_1 = generate_polynomial("SPX")
df_2 = generate_polynomial("NDX")

df_strategy = single_option_downside_short_gu(df_1.copy(), 2, 1, 1, 200, 100, 0)
df_pnl = calculate_pnl(df_strategy)

df_strategy_2 = single_option_downside_short_gu(df_2.copy(), 2, 1, 1, 200, 100, 0)
df_pnl_2 = calculate_pnl(df_strategy_2)

# df_strategy_3 = single_option_upside_long_dugu(df.copy(), 2, 1, 1, 200, 15, 15)
# df_pnl_3 = calculate_pnl(df_strategy_3)

# Plot multiple lines
plt.figure(figsize=(10, 6))
plt.plot(df_pnl["date"], df_pnl["Cumulative PnL"], label = "SPX Puts")
plt.plot(df_pnl_2["date"], 0.25*df_pnl_2["Cumulative PnL"], label = "NDX Puts")
# plt.plot(df_pnl_3["date"], df_pnl_3["Cumulative PnL"], label = "delta and gamma unhedged")


# Add labels, title, and legend
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Multiple Lines on One Chart")
plt.legend()

# Show the plot
plt.show()
# Out:
# c:\Users\ryant\OneDrive\Desktop\Options Pricing Analysis\Backtest Engine\strategy_builder.py:128: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '60.49428198276722' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, "PnL"] = pnl
# c:\Users\ryant\OneDrive\Desktop\Options Pricing Analysis\Backtest Engine\strategy_builder.py:128: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-18.043567016029087' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i, "PnL"] = pnl
